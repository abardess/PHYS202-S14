# %% [markdown]
# # Error Handling Exercises

# %% [markdown]
# Find a partner. Choose a driver and a navigator. The driver should copy their Battleship code to a cell in the driver's ErrorHandlingExercises notebook. The driver should explain to the navigator the basics of how their program works. Work together to add some error handling to the program. Include a markdown cell identifying the driver and navigator. When you are done, switch roles and let the navigator be the driver and vice versa. At the end you should both have a Battleship program that includes some error handling.

# %% [markdown]
# Driver: Anthony Bardessono
#
# Navigator: Dylan Love

# %%
from random import randint
from ipythonblocks import BlockGrid

board = BlockGrid(10,10, fill = (0,0,255))

def random_row(board):
    return randint(0, board.width - 1)

def random_col(board):
    return randint(0, board.height - 1)

ship_row = random_row(board)
ship_col = random_col(board)

turn = 0
x = randint(1, 50)

if x >= 25:
    ship = ship_row
else:
    ship = ship_col

if ship == ship_row:
    if (ship + 1) > board.width: 
        ship_aft = ship - 1
    elif (ship - 1) < board.width:
        ship_aft = ship + 1
    else:
        ship_aft = ship + 1

if ship == ship_col:
    if (ship + 1) > board.height: 
        ship_aft = ship - 1
    elif (ship - 1) < board.height:
        ship_aft = ship + 1
    else:
        ship_aft = ship - 1

print "Let's play Battleship!"
board.show()

for turn in range(8):
    print "Turn:", turn + 1
    try:                                                        #error handling for non-integer input
        guess_row = int(raw_input("Guess Row:"))
        guess_col = int(raw_input("Guess Col:"))
    except ValueError as err:
        if turn == 7:
            print 'Please enter a whole number'
            ship = board[ship_row, ship_col]
            if x >= 25:
                aft = board[ship_row, ship_aft]
            else:
                aft = board[ship_aft, ship_col]
            aft.red = 255
            aft.green = 255
            aft.blue = 0
            print "Game Over"
            print "Here I am!"
            ship.red = 255
            ship.green = 255
            ship.blue = 0            
            board.show()  
        else:
            print 'Please enter a whole number'
            board.show()                                       #end error handling
    else:
        if (guess_row < 0 or guess_row > (board.width - 1)) or (guess_col < 0 or guess_col > (board.height - 1)):
            print "Oops, that's not even in the ocean."
            board.show()
        elif (board[ship_row, ship_col].red != 255 and ((board[ship_row, ship_aft].red != 255) or (board[ship_aft, ship_col].red != 255))):
            square = board[guess_row, guess_col]
            if(square.green == 255 or square.red == 255):
                print "You guessed that one already."
            elif (guess_row == ship_row and guess_col == ship_col) or (guess_row == ship_aft and guess_col == ship_col) or (guess_row == ship_row and guess_col == ship_aft):
                print "You hit my battleship!" 
                square.blue = 0
                square.red = 255
            else:
                print "You missed my battleship!"
                square.green = 255
                square.blue = 0
            if turn == 7:
                ship = board[ship_row, ship_col]
                if x >= 25:
                    aft = board[ship_row, ship_aft]
                else:
                    aft = board[ship_aft, ship_col]
                aft.red = 255
                aft.green = 255
                aft.blue = 0
                print "Game Over"
                print "Here I am!"
                ship.red = 255
                ship.green = 255
                ship.blue = 0            
            board.show()
        else:
            square = board[guess_row, guess_col]
            square.red = 255
            square.blue = 0
            board.show()
            print "Congratulations! You win!"
            break
# Out:
# Let's play Battleship!
# ...

# %% [markdown]
# Here is a function which takes a filename, opens the file, reads the result, closes the file, and returns the contents.
#
# Use runtime error handling concepts to improve this function, so that it does the following:
#
#
# Raises an informative custom error if the file doesn't exist
#
#
# Uses try, except, else, and/or finally to safely return the file's contents & close the file if necessary.
#
#
# Add a keyword safe which defaults to False. If the function is called with safe=True, then return an empty string if the file doesn't exist.

# %%
def read_all_from_file(filename, safe = False):
    try:
        f = open(filename)
        contents = f.read()
        f.close()
        print contents
        return contents
    except IOError as err:
        if safe == True:
            return str( )
        else:
            print "That file does not exist."

read_all_from_file('tmp.txt')

read_all_from_file('file.which.does.not.exist')

read_all_from_file('file.which.does.not.exist', safe = True)
# Out:
# this is the contents of the file
# That file does not exist.
# ''
